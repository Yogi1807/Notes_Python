# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("movies_data.csv")
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.groupby("genre").groups.keys()
# Out:
# dict_keys(['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime', 'Drama', 'Family', 'Fantasy', 'Film-Noir', 'History', 'Horror', 'Mystery', 'Sci-Fi', 'Thriller', 'Western'])

# %%
df["genre"].nunique()
# Out:
# 16

# %%
df.groupby("genre").first()
# Out:
#            star_rating                                          title  \
# genre
# Action             9.0                                The Dark Knight
# Adventure          8.9  The Lord of the Rings: The Return of the King
# Animation          8.6                                  Spirited Away
# Biography          8.9                               Schindler's List
# Comedy             8.6                              Life Is Beautiful
# Crime              9.3                       The Shawshank Redemption
# Drama              8.9                                   12 Angry Men
# Family             7.9                     E.T. the Extra-Terrestrial
# Fantasy            7.7                      The City of Lost Children
# Film-Noir          8.3                                  The Third Man
# History            8.0                            Battleship Potemkin
# Horror             8.6                                         Psycho
# ...

# %%
df.groupby("title").first()
# Out:
#                        star_rating content_rating      genre  duration  \
# title
# (500) Days of Summer           7.8          PG-13     Comedy        95
# 12 Angry Men                   8.9      NOT RATED      Drama        96
# 12 Years a Slave               8.1              R  Biography       134
# 127 Hours                      7.6              R  Adventure        94
# 2001: A Space Odyssey          8.3              G    Mystery       160
# ...                            ...            ...        ...       ...
# Zero Dark Thirty               7.4              R      Drama       157
# Zodiac                         7.7              R      Crime       157
# Zombieland                     7.7              R     Comedy        88
# Zulu                           7.8        UNRATED      Drama       138
# [Rec]                          7.5              R     Horror        78
#
#                                                              actors_list
# title
# ...

# %%
df.groupby("genre").get_group("History")
# Out:
#      star_rating                title content_rating    genre  duration  \
# 338          8.0  Battleship Potemkin        UNRATED  History        66
#
#                                            actors_list
# 338  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...

# %%
df_drama = df.groupby("genre").get_group("Drama")
df_drama.to_csv("Drama_movies.csv")

# %%
df.groupby("content_rating").get_group("PG-13")
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 13           8.8                                       Forrest Gump
# ..           ...                                                ...
# 964          7.4                                            Lincoln
# 965          7.4                                          Limitless
# 966          7.4                                 The Simpsons Movie
# 973          7.4                              The Cider House Rules
# 976          7.4    Master and Commander: The Far Side of the World
#
#     content_rating      genre  duration  \
# 3            PG-13     Action       152
# 7            PG-13  Adventure       201
# ...

# %%
df.groupby(["content_rating","genre"]).get_group(("PASSED","Comedy"))
# Out:
#      star_rating              title content_rating   genre  duration  \
# 29           8.6        City Lights         PASSED  Comedy        87
# 293          8.1          Duck Soup         PASSED  Comedy        68
# 358          8.0  The Lady Vanishes         PASSED  Comedy        96
#
#                                            actors_list
# 29   [u'Charles Chaplin', u'Virginia Cherrill', u'F...
# 293    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 358  [u'Margaret Lockwood', u'Michael Redgrave', u'...

# %%
df.groupby("genre")["duration"].max()
# Out:
# genre
# Action       205
# Adventure    224
# Animation    134
# Biography    202
# Comedy       187
# Crime        229
# Drama        242
# Family       115
# Fantasy      112
# Film-Noir    111
# History       66
# Horror       146
# Mystery      160
# Sci-Fi       132
# Thriller     120
# Western      175
# Name: duration, dtype: int64

# %%
df.loc[df["content_rating"] == "R"]
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 968          7.4       The English Patient              R      Drama
# 969          7.4       Law Abiding Citizen              R      Crime
# 970          7.4               Wonder Boys              R      Drama
# 971          7.4        Death at a Funeral              R     Comedy
# 978          7.4               Wall Street              R      Crime
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
df.loc[(df["content_rating"] == "R") & (df["genre"] == "Action")]
# Out:
#      star_rating                       title content_rating   genre  duration  \
# 20           8.7                  The Matrix              R  Action       136
# 36           8.6         Saving Private Ryan              R  Action       169
# 44           8.5                   Gladiator              R  Action       155
# 45           8.5  Terminator 2: Judgment Day              R  Action       137
# 75           8.4                      Aliens              R  Action       137
# ..           ...                         ...            ...     ...       ...
# 885          7.5                Total Recall              R  Action       113
# 906          7.5                      Looper              R  Action       119
# 918          7.5              Running Scared              R  Action       122
# 963          7.4             La Femme Nikita              R  Action       118
# 967          7.4                    The Rock              R  Action       136
#
# ...

# %%
df.loc[(df["content_rating"] == "R") & (df["genre"] == "Action") | (df["genre"] =="Crime")]
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 1            9.2             The Godfather              R   Crime       175
# 2            9.1    The Godfather: Part II              R   Crime       200
# 4            8.9              Pulp Fiction              R   Crime       154
# 20           8.7                The Matrix              R  Action       136
# ..           ...                       ...            ...     ...       ...
# 950          7.4                     Bound              R   Crime       108
# 963          7.4           La Femme Nikita              R  Action       118
# 967          7.4                  The Rock              R  Action       136
# 969          7.4       Law Abiding Citizen              R   Crime       109
# 978          7.4               Wall Street              R   Crime       126
#
#                                            actors_list
# ...

# %%
df.loc[(df["content_rating"] == "R") 
       & (df["genre"] == "Action") 
       | (df["genre"] =="Crime")
      & (df["duration"] <=180)
      & (df["duration"] >=120)]
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 1            9.2             The Godfather              R   Crime       175
# 4            8.9              Pulp Fiction              R   Crime       154
# 20           8.7                The Matrix              R  Action       136
# 21           8.7               City of God              R   Crime       130
# ..           ...                       ...            ...     ...       ...
# 918          7.5            Running Scared              R  Action       122
# 924          7.5            Les Miserables          PG-13   Crime       134
# 963          7.4           La Femme Nikita              R  Action       118
# 967          7.4                  The Rock              R  Action       136
# 978          7.4               Wall Street              R   Crime       126
#
#                                            actors_list
# ...
