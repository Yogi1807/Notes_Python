# %% [markdown]
# # Exercise 1

# %%
class Shape:

    unit = "meters"  # class attribute
    
    # super-class of all the classes for all sizes and shapes
    # TODO - replace pass statement with your any imaginable attributes
    # TODO - keep some of the attributes as class attributes and some as instance attributes
    # TODO - instance attributes should be of all three categories (public, private, protected)
    # TODO - write getters and setter methods for all the private instance attributes
    # TODO -  provide @property getter and setter method to manipulate protected instance attributes
    pass

    def convert_dimension_to_cm(self, dimension):
        if self.unit == "meters":
            return dimension * 100
        

class Triangle(Shape):

    # TODO - define a method to find area of triangle
    # TODO - apply concept of method either of overloading and overriding in child classes (as needed)
    pass


class RightAngleTriangle(Triangle):
    pass


class Circle(Shape):
    # TODO - define a method to find area of circle
    # TODO - `get_value_of_pi()` method should be defined in the parent class and
    #  override the parent class method with overloaded value of PI
    pass


class Quadrilateral(Shape):
    
    # TODO - overload the method `convert_dimension_to_cm` defined in parent class (Shape)
    #  to pass another unit on dimension like feet.
    pass


class Square(Quadrilateral):
    pass


class Rectangle(Square):
    pass

# %% [markdown]
# # Exercise 2

# %%
class Person(object):
    # TODO - add doc-string here
    def __init__(self, name):
        self.name = name  # TODO - add more instance attributes here

    def get_details(self):
        # TODO - add docstring here
        
        # TODO - return details by combining instance attributes defined in the constructor method
        return self.name 


class Employee(Person):
    """
    Returns a ```Employee``` object, takes 3 arguments, name, salary, designation

    """
    
    # TODO - declare some class attributes here
    
    def __init__(self, *args, **kwargs):
        super().__init__()  # TODO - use some of the positional and keyword arguments to instantiate parent class object
        # TODO - use some of the positional and keyword arguments to instantiate `Employee` class object
        # TODO - remove pass statement
        pass

    def get_details(self):
        """Returns a string containing employees's details."""

        return "%s studies %s and is in %s year." % (self.name, self.branch, self.year)


    def convert_salary_in_dollars(self):
        # TODO - assuming you've defined an instance attribute called `_salary` in constructor
        # TODO - do the forex conversion (INR -> USD)
        # TODO - use internet to check current dollar rate against indian rupees


class Teacher(Person):
    """
    Returns a ```Teacher``` object, takes a list of strings (list of topics) as
    argument.
    """
    def __init__(self, name, topics):
        super().__init__(name)
        self.topics = topics

    def get_details(self):
        return "%s teaches %s" % (self.name, ','.join(self.topics))


# TODO - print additional details from the object of each class similar in the following manner.

person1 = Person('Virat')
emp1 = Employee('Hardik', 'Sr Manager', 8989898)
teacher1 = Teacher('Prashant', ['C', 'C++'])

print(person1.get_details())
print(emp1.get_details())
print(teacher1.get_details())
