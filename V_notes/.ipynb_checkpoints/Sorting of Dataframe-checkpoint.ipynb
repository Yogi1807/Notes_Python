# %%
import pandas as pd
import numpy as np

# %%
sorting:
    1.df.sort_index()
    2.df.sort_values()
    3.df.reset_index()
    4.df.set_index()

# %%
df = pd.read_excel("Emp_Records.xlsx")
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# #    1.df.sort_index()

# %%
df.sort_index()
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=0)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_index(axis=1)
# Out:
#     Age in Company  Age in Yrs          City  Emp ID First Name  Salary  \
# 0            13.68       36.36        Denver  677509       Lois  168251
# 1             9.01       47.02     Stonewall  940761     Brenda   51063
# 2             0.98       54.15  Michigantown  428945        Joe   50155
# 3            18.30       39.67      Hydetown  408351      Diane  180294
# 4             4.01       40.31       Fremont  193819   Benjamin  117642
# ..             ...         ...           ...     ...        ...     ...
# 95            1.05       22.82        Biloxi  639892       Jose  129774
# 96            5.93       32.61  Carol Stream  704709     Harold  156194
# 97           28.53       52.66       Detroit  461593     Nicole   95673
# 98            6.99       29.60      Mc Grath  392491    Theresa   51015
# 99            2.26       38.38          Alma  495141      Tammy   93650
#
#     Weight in Kgs
# 0             NaN
# 1             NaN
# 2            68.0
# 3            51.0
# ...

# %%
df1 = pd.DataFrame(np.random.randint(10,100,size=(6,4)))
# Out:
#     0   1   2   3
# 0  10  10  91  84
# 1  91  71  95  76
# 2  11  69  71  15
# 3  91  78  65  15
# 4  37  57  99  69
# 5  88  94  49  89

# %%
array = np.random.randint(10,100,size=(6,4))

df2 = pd.DataFrame(array,index=list("python"))
df2
# Out:
#     0   1   2   3
# p  12  75  26  80
# y  68  97  92  96
# t  88  88  87  98
# h  69  93  71  73
# o  43  70  80  48
# n  30  59  47  31

# %%
df2.sort_index(axis=0)
# Out:
#     0   1   2   3
# h  69  93  71  73
# n  30  59  47  31
# o  43  70  80  48
# p  12  75  26  80
# t  88  88  87  98
# y  68  97  92  96

# %% [markdown]
# # 2.sort_values()

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_values("Age in Yrs")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 13  301576      Wayne       21.10           87.0            0.02   92758
# 49  879753     Pamela       21.30           47.0            0.13  149262
# 59  750173    Antonio       21.93           82.0            0.24  181646
# 6   539712      Nancy       22.14           50.0            0.87   98189
# 11  153989       Jack       22.21           61.0            0.56   82965
# ..     ...        ...         ...            ...             ...     ...
# 74  528673       Paul       58.43           60.0           22.10  145235
# 7   380086      Carol       59.12           40.0           34.52   60918
# 57  515103       Anne       59.27           48.0           14.01  114426
# 24  560455    Carolyn       59.42           53.0           16.08   42005
# 14  441771     Cheryl       59.47           47.0           26.69   92220
#
#            City
# 13        Maida
# 49       Banner
# 59     Mc Calla
# 6       Atlanta
# ...

# %%
df.sort_values("First Name")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 36  218791      Aaron       48.49           56.0           20.08   54402
# 43  247137       Alan       38.65           80.0           11.15  154810
# 41  227922     Amanda       35.02           40.0           10.28  114257
# 31  893212        Amy       36.14           52.0           14.17  112715
# 66  183071     Andrea       32.08           52.0            7.28   54179
# ..     ...        ...         ...            ...             ...     ...
# 17  214352    Theresa       24.66           59.0            2.52  197537
# 19  622406     Thomas       49.85           73.0           19.15   73862
# 64  917937       Todd       25.93           74.0            1.22  163560
# 13  301576      Wayne       21.10           87.0            0.02   92758
# 78  806955    William       50.05           50.0           17.36   73734
#
#             City
# 36       Eckerty
# 43     Knoxville
# 41  Lake Charles
# 31         Kline
# ...

# %%
df.sort_values(["Weight in Kgs", "Age in Yrs"])
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 75  765850      Linda       25.96           40.0            0.20  113256
# 41  227922     Amanda       35.02           40.0           10.28  114257
# 47  524896       Judy       56.38           40.0            5.59  133332
# 7   380086      Carol       59.12           40.0           34.52   60918
# 51  447813        Ann       28.23           41.0            3.69  130014
# ..     ...        ...         ...            ...             ...     ...
# 87  623929      Jimmy       50.70           87.0            9.63  120631
# 95  639892       Jose       22.82           89.0            1.05  129774
# 38  726264       Carl       43.63           90.0           10.14  162159
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            9.01   51063
#
#             City
# 75        Albion
# 41  Lake Charles
# 47        Topeka
# 7    Blanchester
# ...

# %%
df.sort_values("Salary",ascending=True)
# Out:
#     Emp ID   First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 24  560455      Carolyn       59.42           53.0           16.08   42005
# 9   162402        Diana       29.73           60.0            3.44   43010
# 72  951225     Margaret       25.10           56.0            0.92   43867
# 60  687017      Frances       56.53           42.0            6.94   46945
# 79  325319      Carolyn       41.19           60.0            2.73   48736
# ..     ...          ...         ...            ...             ...     ...
# 71  478003      Cynthia       54.16           60.0           13.41  186200
# 42  265813         Jack       32.58           50.0           10.01  186280
# 55  253573       Sharon       26.25           43.0            3.39  190139
# 65  917395  Christopher       57.37           62.0           19.73  190765
# 17  214352      Theresa       24.66           59.0            2.52  197537
#
#               City
# 24     Saint Cloud
# 9   Eureka Springs
# ...

# %%
df.sort_values("Salary",ascending=False)
# Out:
#     Emp ID   First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 17  214352      Theresa       24.66           59.0            2.52  197537
# 65  917395  Christopher       57.37           62.0           19.73  190765
# 55  253573       Sharon       26.25           43.0            3.39  190139
# 42  265813         Jack       32.58           50.0           10.01  186280
# 71  478003      Cynthia       54.16           60.0           13.41  186200
# ..     ...          ...         ...            ...             ...     ...
# 79  325319      Carolyn       41.19           60.0            2.73   48736
# 60  687017      Frances       56.53           42.0            6.94   46945
# 72  951225     Margaret       25.10           56.0            0.92   43867
# 9   162402        Diana       29.73           60.0            3.44   43010
# 24  560455      Carolyn       59.42           53.0           16.08   42005
#
#               City
# 17     Toeterville
# 65    Willow Beach
# ...

# %% [markdown]
# # 3. reset_index()

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.sort_values("Weight in Kgs")
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 41  227922     Amanda       35.02           40.0           10.28  114257
# 47  524896       Judy       56.38           40.0            5.59  133332
# 75  765850      Linda       25.96           40.0            0.20  113256
# 7   380086      Carol       59.12           40.0           34.52   60918
# 51  447813        Ann       28.23           41.0            3.69  130014
# ..     ...        ...         ...            ...             ...     ...
# 82  761821     Ernest       32.77           87.0            2.49  176675
# 95  639892       Jose       22.82           89.0            1.05  129774
# 38  726264       Carl       43.63           90.0           10.14  162159
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            9.01   51063
#
#             City
# 41  Lake Charles
# 47        Topeka
# 75        Albion
# 7    Blanchester
# ...

# %%
df.sort_values("Weight in Kgs")
df.reset_index(drop=True)
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %% [markdown]
# # 4.set_index()

# %%
df
# Out:
#     Emp ID First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# 0   677509       Lois       36.36            NaN           13.68  168251
# 1   940761     Brenda       47.02            NaN            9.01   51063
# 2   428945        Joe       54.15           68.0            0.98   50155
# 3   408351      Diane       39.67           51.0           18.30  180294
# 4   193819   Benjamin       40.31           58.0            4.01  117642
# ..     ...        ...         ...            ...             ...     ...
# 95  639892       Jose       22.82           89.0            1.05  129774
# 96  704709     Harold       32.61           77.0            5.93  156194
# 97  461593     Nicole       52.66           60.0           28.53   95673
# 98  392491    Theresa       29.60           57.0            6.99   51015
# 99  495141      Tammy       38.38           55.0            2.26   93650
#
#             City
# 0         Denver
# 1      Stonewall
# 2   Michigantown
# 3       Hydetown
# ...

# %%
df.set_index("Emp ID")
# Out:
#        First Name  Age in Yrs  Weight in Kgs  Age in Company  Salary  \
# Emp ID
# 677509       Lois       36.36            NaN           13.68  168251
# 940761     Brenda       47.02            NaN            9.01   51063
# 428945        Joe       54.15           68.0            0.98   50155
# 408351      Diane       39.67           51.0           18.30  180294
# 193819   Benjamin       40.31           58.0            4.01  117642
# ...           ...         ...            ...             ...     ...
# 639892       Jose       22.82           89.0            1.05  129774
# 704709     Harold       32.61           77.0            5.93  156194
# 461593     Nicole       52.66           60.0           28.53   95673
# 392491    Theresa       29.60           57.0            6.99   51015
# 495141      Tammy       38.38           55.0            2.26   93650
#
#                 City
# Emp ID
# 677509        Denver
# 940761     Stonewall
# 428945  Michigantown
# 408351      Hydetown
# ...
