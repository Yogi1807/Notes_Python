# %% [markdown]
# ## Pandas

# %%
Pandas >> Python Data Analysis  >>> used in data analysis

# %%
Two types of Data Structure
1. Series >>> (1D data)>> single column data
2. DataFrame >>> (2D Data)>> multiple column data

# %% [markdown]
# ### DataFrame

# %%
1. 2-Dimentional Data
2. Table with rows and columns
3. Mutable (add, update, delete)

# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([1,2,4,5,np.nan,8])
s
# Out:
# 0    1.0
# 1    2.0
# 2    4.0
# 3    5.0
# 4    NaN
# 5    8.0
# dtype: float64

# %%
df=pd.DataFrame({"A":1.0,
                "B":pd.Timestamp("20230414"),
                "C":pd.Series(1,index=list(range(4))),
                "D":np.array([3]*4),
                "E":pd.Categorical(['True','False','True','False']),
                "F":"PythonDev"})
df
# Out:
#      A          B  C  D      E          F
# 0  1.0 2023-04-14  1  3   True  PythonDev
# 1  1.0 2023-04-14  1  3  False  PythonDev
# 2  1.0 2023-04-14  1  3   True  PythonDev
# 3  1.0 2023-04-14  1  3  False  PythonDev

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %% [markdown]
# ### Uses

# %%
1. used to work with datasets
2. Analysis
3. cleaning
4. manipulating data
5. to join multiple csv/excel files or joining tables
6. It can handle messy data.
7. correlation

# %% [markdown]
# ### How to create DataFrame

# %%
Exsisting Data:
1. CSV file
2. excel file
3. JSON file
4. Database

New Dataframe:
1. list
2. Dict
3. numpy array

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
array=np.random.randint(20,40,size=(6,4))
array
# Out:
# array([[30, 38, 33, 29],
#        [20, 35, 32, 27],
#        [36, 21, 26, 37],
#        [36, 24, 38, 34],
#        [32, 28, 20, 37],
#        [29, 20, 37, 20]])

# %%
df3=pd.DataFrame(array)
df3
# Out:
#     0   1   2   3
# 0  30  38  33  29
# 1  20  35  32  27
# 2  36  21  26  37
# 3  36  24  38  34
# 4  32  28  20  37
# 5  29  20  37  20

# %%
df3=pd.DataFrame(array,columns=list("ABCD"),index=list('python'))
df3
# Out:
#     A   B   C   D
# p  30  38  33  29
# y  20  35  32  27
# t  36  21  26  37
# h  36  24  38  34
# o  32  28  20  37
# n  29  20  37  20

# %%
df3.axes
# Out:
# [Index(['p', 'y', 't', 'h', 'o', 'n'], dtype='object'),
#  Index(['A', 'B', 'C', 'D'], dtype='object')]

# %%
df3.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df3.index
# Out:
# Index(['p', 'y', 't', 'h', 'o', 'n'], dtype='object')

# %% [markdown]
# ### Read CSV file

# %%
df4=pd.read_csv('Customers.csv')
df4
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df4.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
df4.axes
# Out:
# [RangeIndex(start=0, stop=200, step=1),
#  Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#         'Spending Score (1-100)'],
#        dtype='object')]

# %%
df4.shape
# Out:
# (200, 5)

# %%
df4.shape[0] #>>>> no. of rows
# Out:
# 200

# %%
df4.shape[1] #>>>> no. of columns
# Out:
# 5

# %%
df4[['CustomerID','Genre']]
# Out:
#      CustomerID   Genre
# 0             1    Male
# 1             2    Male
# 2             3  Female
# 3             4  Female
# 4             5  Female
# ..          ...     ...
# 195         196  Female
# 196         197  Female
# 197         198    Male
# 198         199    Male
# 199         200    Male
#
# [200 rows x 2 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df4.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df4
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
first few lines >> df.head()

# %%
df4.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df4.head(8)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94

# %%
last few lines >> df.tail()

# %%
df4.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df4.tail(10)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 190         191  Female   34                 103                      23
# 191         192  Female   32                 103                      69
# 192         193    Male   33                 113                       8
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %% [markdown]
# ### access data from Dataframe

# %% [markdown]
# ## 1. Slicing

# %%
df4[10:20]
# Out:
#     CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 10          11    Male   67                  19                      14
# 11          12  Female   35                  19                      99
# 12          13  Female   58                  20                      15
# 13          14  Female   24                  20                      77
# 14          15    Male   37                  20                      13
# 15          16    Male   22                  20                      79
# 16          17  Female   35                  21                      35
# 17          18    Male   20                  21                      66
# 18          19    Male   52                  23                      29
# 19          20  Female   35                  23                      98

# %%
df4[['CustomerID','Genre','Age']]
# Out:
#      CustomerID   Genre  Age
# 0             1    Male   19
# 1             2    Male   21
# 2             3  Female   20
# 3             4  Female   23
# 4             5  Female   31
# ..          ...     ...  ...
# 195         196  Female   35
# 196         197  Female   45
# 197         198    Male   32
# 198         199    Male   32
# 199         200    Male   30
#
# [200 rows x 3 columns]

# %%
df4['Genre'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Genre, dtype: int64

# %% [markdown]
# ### 1. Detect Null Values

# %%
df4.isnull()
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False               False                   False
# 1         False  False  False               False                   False
# 2         False  False  False               False                   False
# 3         False  False  False               False                   False
# 4         False  False  False               False                   False
# ..          ...    ...    ...                 ...                     ...
# 195       False  False  False               False                   False
# 196       False  False  False               False                   False
# 197       False  False  False               False                   False
# 198       False  False  False               False                   False
# 199       False  False  False               False                   False
#
# [200 rows x 5 columns]

# %%
df4.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df4.isna().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df4
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df4['Age']=np.nan

# %%
df4
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  NaN                  15                      39
# 1             2    Male  NaN                  15                      81
# 2             3  Female  NaN                  16                       6
# 3             4  Female  NaN                  16                      77
# 4             5  Female  NaN                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female  NaN                 120                      79
# 196         197  Female  NaN                 126                      28
# 197         198    Male  NaN                 126                      74
# 198         199    Male  NaN                 137                      18
# 199         200    Male  NaN                 137                      83
#
# [200 rows x 5 columns]

# %%
df4.isnull()
# Out:
#      CustomerID  Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  True               False                   False
# 1         False  False  True               False                   False
# 2         False  False  True               False                   False
# 3         False  False  True               False                   False
# 4         False  False  True               False                   False
# ..          ...    ...   ...                 ...                     ...
# 195       False  False  True               False                   False
# 196       False  False  True               False                   False
# 197       False  False  True               False                   False
# 198       False  False  True               False                   False
# 199       False  False  True               False                   False
#
# [200 rows x 5 columns]

# %%
df4.isnull().sum()
# Out:
# CustomerID                  0
# Genre                       0
# Age                       200
# Annual Income (k$)          0
# Spending Score (1-100)      0
# dtype: int64

# %%
df4.isna().sum()
# Out:
# CustomerID                  0
# Genre                       0
# Age                       200
# Annual Income (k$)          0
# Spending Score (1-100)      0
# dtype: int64

# %% [markdown]
# ### to fill null values

# %%
df.fillna(value,inplace=False)

# %%
df4.fillna(50)
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male  50.0                  15                      39
# 1             2    Male  50.0                  15                      81
# 2             3  Female  50.0                  16                       6
# 3             4  Female  50.0                  16                      77
# 4             5  Female  50.0                  17                      40
# ..          ...     ...   ...                 ...                     ...
# 195         196  Female  50.0                 120                      79
# 196         197  Female  50.0                 126                      28
# 197         198    Male  50.0                 126                      74
# 198         199    Male  50.0                 137                      18
# 199         200    Male  50.0                 137                      83
#
# [200 rows x 5 columns]

# %%
df4
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df4.nunique()  > unique values in Dataframe
# Out:
# CustomerID                200
# Genre                       2
# Age                        51
# Annual Income (k$)         64
# Spending Score (1-100)     84
# dtype: int64

# %%
df4['Genre'].value_counts()
# Out:
# Female    112
# Male       88
# Name: Genre, dtype: int64

# %%
df4['Age'].value_counts()
# Out:
# 32    11
# 35     9
# 31     8
# 19     8
# 30     7
# 49     7
# 40     6
# 38     6
# 36     6
# 47     6
# 23     6
# 27     6
# 20     5
# 48     5
# 21     5
# 34     5
# 50     5
# 29     5
# 28     4
# 24     4
# 54     4
# 67     4
# 59     4
# 18     4
# 68     3
# 60     3
# 46     3
# 43     3
# 45     3
# 22     3
# 25     3
# 39     3
# 37     3
# 33     3
# 58     2
# 66     2
# 65     2
# 63     2
# 26     2
# 57     2
# 44     2
# 53     2
# 52     2
# 51     2
# 41     2
# 42     2
# 70     2
# 56     1
# 55     1
# 64     1
# 69     1
# Name: Age, dtype: int64

# %%
df4.to_csv("Developement.csv")

# %%
df4.to_json('today.json')

# %%
df5=pd.read_json('today.json')
df5
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df5.to_excel("sheet.xlsx")

# %%
excel with multiple sheet
1. writer=pd.ExcelWriter('name')
2. df1.to_excel(writer)
3. df2.to_excel(writer)
4. writer.save()

# %%
df6=pd.read_excel('sheet.xlsx')
df6
# Out:
#      Unnamed: 0  CustomerID   Genre  Age  Annual Income (k$)  \
# 0             0           1    Male   19                  15
# 1             1           2    Male   21                  15
# 2             2           3  Female   20                  16
# 3             3           4  Female   23                  16
# 4             4           5  Female   31                  17
# ..          ...         ...     ...  ...                 ...
# 195         195         196  Female   35                 120
# 196         196         197  Female   45                 126
# 197         197         198    Male   32                 126
# 198         198         199    Male   32                 137
# 199         199         200    Male   30                 137
#
#      Spending Score (1-100)
# 0                        39
# 1                        81
# 2                         6
# 3                        77
# 4                        40
# ..                      ...
# ...
